# %%
import os
import yt_dlp
os.chdir('data')

# %%
import PyPDF2
pdf1 = 'pdfcoffee.com_advanced-calisthenics-superhuman-domination-pdf-free.pdf'
pdf2= 'kupdf.net_intermediate-calisthenics-superhuman-rising.pdf'
PDFFile = open(pdf2,'rb')
ydl_opts = {'writesubtitles': True, 'skip-download': True}
PDF = PyPDF2.PdfFileReader(PDFFile)
pages = PDF.getNumPages()
key = '/Annots'
uri = '/URI'
ank = '/A'

for page in range(pages):
    print("Current Page: {}".format(page))
    pageSliced = PDF.getPage(page)
    pageObject = pageSliced.getObject()
    if key in pageObject.keys():
        ann = pageObject[key]
        for a in ann:
            u = a.getObject()
            if uri in u[ank].keys():
                print(u[ank][uri])
                try:
                    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                        ydl.download([u[ank][uri]])
                except:
                    pass
# Out:
# Current Page: 0
# Current Page: 1
# Current Page: 2
# Current Page: 3
# Current Page: 4
# Current Page: 5
# Current Page: 6
# Current Page: 7
# Current Page: 8
# Current Page: 9
# Current Page: 10
# Current Page: 11
# https://www.youtube.com/watch?v=O-97uCIRen0
# [youtube] O-97uCIRen0: Downloading webpage
# [youtube] O-97uCIRen0: Downloading android player API JSON
# [info] O-97uCIRen0: Downloading 1 format(s): 248+251
# [download] SHOULDER WARM UP [O-97uCIRen0].webm has already been downloaded
# Current Page: 12
# Current Page: 13
# Current Page: 14
# https://www.youtube.com/watch?v=68kTBjO0xTo
# [youtube] 68kTBjO0xTo: Downloading webpage
# [youtube] 68kTBjO0xTo: Downloading android player API JSON
# [info] 68kTBjO0xTo: Downloading 1 format(s): 248+251
# [download] HIGH PULL UPS ⧸ STRAIGHT BAR DIPS [68kTBjO0xTo].webm has already been downloaded
# https://www.youtube.com/watch?v=JqSvROdqKwE
# [youtube] JqSvROdqKwE: Downloading webpage
# ...
